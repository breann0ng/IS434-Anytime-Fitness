# %% [markdown]
# Data Preprocessing:
# - Remove/ replace missing values

# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in /Users/breann/anaconda3/lib/python3.11/site-packages (2.32.4)
# Requirement already satisfied: pandas in /Users/breann/anaconda3/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/breann/anaconda3/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/breann/anaconda3/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/breann/anaconda3/lib/python3.11/site-packages (from requests) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/breann/anaconda3/lib/python3.11/site-packages (from requests) (2025.8.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/breann/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/breann/anaconda3/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/breann/anaconda3/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/breann/anaconda3/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/breann/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import r2_score

# %% [markdown]
# Scraping from Google Reviews:

# %%
import time

# %%
API_KEY = "AIzaSyC6M-BJbnUubBk1CvFVoxdC21_zxdsaCSE"
SEARCH_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"
DETAILS_URL = "https://maps.googleapis.com/maps/api/place/details/json"

locations = [
    (1.3521, 103.8198),  # Central
    (1.2800, 103.8500),  # Downtown
    (1.3000, 103.9000),  # East
    (1.3400, 103.7000),  # West
    (1.4000, 103.9000),  # North
    (1.3700, 103.7700),  # Northwest
    (1.3100, 103.8400),  # Central South
    (1.3300, 103.9300),  # East Coast
]

# === FETCH ALL OUTLETS ===
def fetch_nearby_anytime_fitness(lat, lng, radius=10000):
    """Fetch Anytime Fitness gyms near given lat/lng."""
    params = {
        "location": f"{lat},{lng}",
        "radius": radius,
        "keyword": "Anytime Fitness",
        "type": "establishment",
        "key": API_KEY
    }

    gyms = []
    while True:
        response = requests.get(SEARCH_URL, params=params)
        data = response.json()

        for r in data.get("results", []):
            name = r.get("name", "")
            if "anytime fitness" not in name.lower():
                continue  # skip non-AF gyms

        
            gyms.append({
                "name": r.get("name"),
                "place_id": r.get("place_id"),
                "address": r.get("vicinity"),
                "rating": r.get("rating"),
                "user_ratings_total": r.get("user_ratings_total")
            })

        token = data.get("next_page_token")
        if not token:
            break

        time.sleep(2)
        params = {"pagetoken": token, "key": API_KEY}

    return gyms


# === FETCH REVIEWS FOR EACH OUTLET ===
def fetch_reviews_for_outlet(place_id, name):
    """Fetch up to 5 reviews for a specific outlet."""
    params = {
        "place_id": place_id,
        "fields": "name,reviews",
        "key": API_KEY
    }
    response = requests.get(DETAILS_URL, params=params)
    data = response.json()
    reviews = data.get("result", {}).get("reviews", [])

    review_list = []
    for rev in reviews:
        review_list.append({
            "outlet_name": name,
            "author": rev.get("author_name"),
            "rating": rev.get("rating"),
            "text": rev.get("text"),
            "time": rev.get("relative_time_description")
        })
    return review_list


# === MAIN WORKFLOW ===
print("🔍 Fetching Anytime Fitness outlets across Singapore...")

all_gyms = []
for lat, lng in locations:
    print(f"📍 Searching around {lat}, {lng}...")
    all_gyms.extend(fetch_nearby_anytime_fitness(lat, lng))
    time.sleep(1)

# Remove duplicates by place_id
df_gyms = pd.DataFrame(all_gyms).drop_duplicates(subset=["place_id"])
print(f"✅ Found {len(df_gyms)} unique outlets.\n")

# Fetch reviews for each outlet
all_reviews = []
for _, row in df_gyms.iterrows():
    print(f"💬 Fetching reviews for: {row['name']}")
    reviews = fetch_reviews_for_outlet(row["place_id"], row["name"])
    all_reviews.extend(reviews)
    time.sleep(1)  # avoid API rate limit

# Step 3: Combine into DataFrame
df_reviews = pd.DataFrame(all_reviews)

print(df_reviews.head())
# Out:
# 🔍 Fetching Anytime Fitness outlets across Singapore...
# 📍 Searching around 1.3521, 103.8198...
# 📍 Searching around 1.28, 103.85...
# 📍 Searching around 1.3, 103.9...
# 📍 Searching around 1.34, 103.7...
# 📍 Searching around 1.4, 103.9...
# 📍 Searching around 1.37, 103.77...
# 📍 Searching around 1.31, 103.84...
# 📍 Searching around 1.33, 103.93...
# ✅ Found 0 unique outlets.
#
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Step 4: Save to CSV
df_reviews.to_csv("anytime_reviews_singapore.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# Sentiment Analysis:

# %%
# !pip install textblob
import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# Requirement already satisfied: textblob in /Users/breann/anaconda3/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /Users/breann/anaconda3/lib/python3.11/site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in /Users/breann/anaconda3/lib/python3.11/site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /Users/breann/anaconda3/lib/python3.11/site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/breann/anaconda3/lib/python3.11/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/breann/anaconda3/lib/python3.11/site-packages (from nltk>=3.9->textblob) (4.67.1)
# [nltk_data] Downloading package brown to /Users/breann/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/breann/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/breann/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from textblob import TextBlob

df = pd.read_csv("anytime_reviews_singapore.csv")
df["sentiment"] = df["text"].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
df["sentiment_label"] = df["sentiment"].apply(
    lambda x: "Positive" if x > 0 else "Negative" if x < 0 else "Neutral"
)

print(df.head())

# Example summary
print(df["sentiment_label"].value_counts())
# Out:
#                    outlet_name          author  rating  \
# 0  Anytime Fitness Clarke Quay  In2rovert Life       5
# 1  Anytime Fitness Clarke Quay   Hisyam Othman       5
# 2  Anytime Fitness Clarke Quay   Corentin Roux       5
# 3  Anytime Fitness Clarke Quay         SC Hung       5
# 4  Anytime Fitness Clarke Quay         Micky P       4
#
#                                                 text              time  \
# 0  Visited tons of AF Worldwide and this is one o...  in the last week
# 1  I'm so lucky to try out this brand new awesome...        a week ago
# 2  An excellent new opening filling the AF desert...        a week ago
# 3  I was lucky to use this place on just their se...        a week ago
# 4  Has that brand new car smell! Awesome gym dens...  in the last week
#
#    sentiment sentiment_label
# 0   0.020068        Positive
# 1   0.496656        Positive
# 2   0.147430        Positive
# 3   0.371667        Positive
# 4   0.451705        Positive
# sentiment_label
# Positive    258
# Negative     24
# Neutral       3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   outlet_name      285 non-null    object
#  1   author           285 non-null    object
#  2   rating           285 non-null    int64
#  3   text             284 non-null    object
#  4   time             285 non-null    object
#  5   sentiment        285 non-null    float64
#  6   sentiment_label  285 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 15.7+ KB

# %%
df.isnull().sum()
# Out:
# outlet_name        0
# author             0
# rating             0
# text               1
# time               0
# sentiment          0
# sentiment_label    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# outlet_name        0
# author             0
# rating             0
# text               0
# time               0
# sentiment          0
# sentiment_label    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 284 entries, 0 to 284
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   outlet_name      284 non-null    object
#  1   author           284 non-null    object
#  2   rating           284 non-null    int64
#  3   text             284 non-null    object
#  4   time             284 non-null    object
#  5   sentiment        284 non-null    float64
#  6   sentiment_label  284 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 17.8+ KB

# %%
df["sentiment_label"].value_counts()
# Out:
# sentiment_label
# Positive    258
# Negative     24
# Neutral       3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                    outlet_name          author  rating  \
# 0  Anytime Fitness Clarke Quay  In2rovert Life       5
# 1  Anytime Fitness Clarke Quay   Hisyam Othman       5
# 2  Anytime Fitness Clarke Quay   Corentin Roux       5
# 3  Anytime Fitness Clarke Quay         SC Hung       5
# 4  Anytime Fitness Clarke Quay         Micky P       4
#
#                                                 text              time  \
# 0  Visited tons of AF Worldwide and this is one o...  in the last week
# 1  I'm so lucky to try out this brand new awesome...        a week ago
# 2  An excellent new opening filling the AF desert...        a week ago
# 3  I was lucky to use this place on just their se...        a week ago
# 4  Has that brand new car smell! Awesome gym dens...  in the last week
#
#    sentiment sentiment_label
# 0   0.020068        Positive
# 1   0.496656        Positive
# 2   0.147430        Positive
# 3   0.371667        Positive
# 4   0.451705        Positive

# %% [markdown]
# Getting Ratings and outlet information:

# %%
import requests
import time

API_KEY = "AIzaSyC6M-BJbnUubBk1CvFVoxdC21_zxdsaCSE"
query = "Anytime Fitness Singapore"

url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={query}&key={API_KEY}"

places = []

while True:
    response = requests.get(url)
    data = response.json()
    
    for place in data.get("results", []):
        name = place.get("name")
        rating = place.get("rating")
        address = place.get("formatted_address")
        places.append((name, rating, address))
    
    # Check for next page
    next_page_token = data.get("next_page_token")
    if not next_page_token:
        break

    # Wait before next request
    time.sleep(2)
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken={next_page_token}&key={API_KEY}"

# Convert to DataFrame (optional)
import pandas as pd
df = pd.DataFrame(places, columns=["Outlet", "Rating", "Address"])
print(df)
# Out:
#                                    Outlet  Rating  \
# 0             Anytime Fitness Tekka Place     4.9
# 1                   Anytime Fitness Bugis     4.7
# 2             Anytime Fitness Clarke Quay     4.9
# 3             Anytime Fitness Jalan Besar     4.2
# 4           Anytime Fitness The Concourse     3.2
# 5               Anytime Fitness City Hall     4.3
# 6        Anytime Fitness City Square Mall     4.9
# 7           Anytime Fitness Raffles Place     4.7
# 8                 Anytime Fitness Orchard     4.7
# 9     Anytime Fitness Cineleisure Orchard     4.8
# 10        Anytime Fitness Havelock Outram     4.9
# 11             Anytime Fitness Kaki Bukit     4.7
# 12               Anytime Fitness Balmoral     4.6
# 13                 Anytime Fitness Dakota     5.0
# 14                 Anytime Fitness Novena     4.4
# 15            Anytime Fitness Bukit Merah     4.4
# 16          Anytime Fitness Tanjong Pagar     4.3
# 17              Anytime Fitness Boon Keng     4.5
# 18        Anytime Fitness MacPherson Mall     5.0
# 19             Anytime Fitness Guillemard     3.6
# 20         Anytime Fitness Wheelock Place     4.8
# 21    Anytime Fitness Bukit Merah Central     4.0
# 22                        Anytime Fitness     4.0
# 23     Anytime Fitness Upper Cross Street     3.5
# 24                 Anytime Fitness Bishan     4.4
# 25           Anytime Fitness Cecil Street     4.0
# 26          Anytime Fitness Geylang Bahru     4.9
# 27        Anytime Fitness Geylang Central     4.7
# 28          Anytime Fitness New Queensway     4.8
# 29         Anytime Fitness Viio@Balestier     4.6
# 30                        Anytime Fitness     NaN
# 31        Anytime Fitness Cantonment Road     4.1
# 32            Anytime Fitness Kim Seng CC     4.8
# 33              Anytime Fitness Balestier     4.4
# 34           Anytime Fitness Aljunied 119     4.0
# 35    Anytime Fitness Bukit Timah Central     4.9
# 36                Anytime Fitness Stevens     4.4
# 37        Anytime Fitness Eastwood Centre     5.0
# 38          Anytime Fitness Labrador View     4.8
# 39              Anytime Fitness Toa Payoh     4.5
# 40      Anytime Fitness Tiong Bahru Plaza     4.2
# 41           Anytime Fitness Valley Point     4.5
# 42          Anytime Fitness Simpang Bedok     5.0
# 43                Anytime Fitness Geylang     4.6
# 44           Anytime Fitness Potong Pasir     4.4
# 45             Anytime Fitness MacPherson     4.1
# 46                24/7 FITNESS The Cathay     5.0
# 47                 Anytime Fitness Keppel     4.4
# 48            Anytime Fitness Buona Vista     4.9
# 49  Anytime Fitness Bedok 200 North Ave 1     4.0
# 50                 Anytime Fitness Katong     4.8
# 51        Anytime Fitness Upper Serangoon     4.9
# 52           Anytime Fitness Clementi 354     4.8
# 53                   24/7 FITNESS Orchard     4.7
# 54            Anytime Fitness Mountbatten     4.6
# 55             Anytime Fitness Paya Lebar     3.7
# 56           Anytime Fitness Harbourfront     4.6
# 57       Anytime Fitness Grantral Complex     4.1
# 58      Anytime Fitness New Upper Thomson     4.8
# 59                 Anytime Fitness Alexis     4.1
#
#                                               Address
# 0   2 Serangoon Rd, #02-17/18/19/20/21, Singapore ...
# 1      51 Middle Rd, #03-01, #04-01, Singapore 188959
# 2   3A River Valley Rd, Clarke Quay, #02-05, Singa...
# 3   Rehau Building 1, 01-00 King George's Ave, Sin...
# 4          300 Beach Rd, #02-01A/02, Singapore 199555
# 5   1 Raffles Link, B1-47 CityLink Mall, Singapore...
# 6   180 Kitchener Road, Mall, #06-04 City Square, ...
# 7             22 Malacca St, #02-01, Singapore 048980
# 8    277 Orchard Rd, #04-01 Orchard, Singapore 238858
# 9               8 Grange Rd, #02-01, Singapore 239695
# 10          405 Havelock Rd, #02-02, Singapore 169633
# 11  1 Kaki Bukit Rd 1, #01-10 Enterprise One, Sing...
# 12  32 Stevens Rd, #02-01 Above Pine Club Mercure ...
# 13  87 Jln. Satu, #02-01 Mountbatten CC, Singapore...
# 14  101 Thomson Road United Square, B1-15 @United ...
# 15  Blk 131 Jalan Bukit Merah, #01-1589/1591, Sing...
# 16  10 Anson Rd, #03-41 International Plaza, Singa...
# 17                294A Lavender St., Singapore 338807
# 18  401 MacPherson Rd, B1-01 MacPherson Mall, Sing...
# 19        100 Guillemard Rd, #01-08, Singapore 399718
# 20        501 Orchard Rd, #05-13/14, Singapore 238880
# 21  Blk 161 Bukit Merah Central, #01-3705, Singapo...
# 22  108 Depot Rd, #03-02 Depot Heights Shopping Ce...
# 23  531 Upper Cross Street #01-07, Hong Lim Comple...
# 24        505 Bishan St.11, #01-438, Singapore 570505
# 25  139 Cecil St, #04-01 YSY Building, Singapore 0...
# 26  1 Geylang Bahru Ln, #01-03 Kolam Ayer Communit...
# 27           301 Geylang Rd, #04-01, Singapore 389344
# 28  Queensway, #03-52, 149053 Queensway Shopping C...
# 29  520 Balestier Rd, #03-01 to #03-04, Singapore ...
# 30  Blk 119 Aljunied Ave 2, #01-80/82/84 South Eas...
# 31                 17 Cantonment Rd, Singapore 089740
# 32  570 Havelock Road 01-14/15 & #02-11/12, 13 Kim...
# 33  288 Balestier Road Balestier, Central, Singapo...
# 34  119 Aljunied Ave 2, #01-80/82/84, Singapore 38...
# 35  559 Bukit Timah Rd, #B1-01 King’s Arcade, Sing...
# 36  383 Bukit Timah Rd, #01-01 01-01, Singapore 25...
# 37  20 Eastwood Rd, #01-03 Eastwood Centre, Singap...
# 38  456 Alexandra Rd, #12-02 Fragrance Empire Buil...
# 39  190 Lor 6 Toa Payoh, #02-516 Above KFC, Singap...
# 40  302 Tiong Bahru Rd, #01-129 Tiong Bahru Plaza,...
# 41  Valley Point Shopping Centre 491, 02-02 River ...
# 42  430 Upper Changi Rd, #01-47/48/49, Singapore 4...
# 43                   653 Geylang Rd, Singapore 389583
# 44  15 Tai Thong Cres, Sennett Estate, Singapore 3...
# 45  400 Paya Lebar Way, #03-05/06 MacPherson Commu...
# 46    2 Handy Rd, #04-04 The Cathay, Singapore 229233
# 47           1557 Keppel Rd, #01-03, Singapore 089066
# 48  11 Biopolis Wy, #01-04/05/06/07 Helios, Singap...
# 49            200 Bedok North Ave 1, Singapore 469752
# 50               174/176 E Coast Rd, Singapore 428880
# 51  780 Upper Serangoon Rd, #01-04/05/06, Singapor...
# 52  Blk 354 Clementi Ave 2, #01-183, Singapore 120354
# 53  9 Scotts Rd, #04-01 Pacific Plaza, Singapore 2...
# 54            372 Tanjong Katong Rd, Singapore 437129
# 55  11 Tanjong Katong Rd, #02 - 01 / 02, KINEX 437157
# 56  3 Harbourfront Pl, HarbourFront Tower Two, Sin...
# 57  605 MacPherson Road, #02-08, Grantral Mall, Gr...
# 58  246S Upper Thomson Rd, New Upper Thomson, Cent...
# 59      354 Alexandra Rd, #01-01/02, Singapore 159948

# %%
df.sort_values(by="Rating", ascending=True).head(5)
# worst outlets
# Out:
#                                  Outlet  Rating  \
# 60        Anytime Fitness The Concourse     3.2
# 136              Anytime Fitness hillV2     3.2
# 117          Anytime Fitness Hwi Yoh CC     3.3
# 35   Anytime Fitness Upper Cross Street     3.5
# 114               Anytime Fitness Kovan     3.6
#
#                                                Address
# 60                 300 Beach Rd, #02-01A/02, Singapore
# 136              4 Hillview Rise, #02-18/19, Singapore
# 117  23 Serangoon North Ave 4, #01-01 Hwi Yoh Commu...
# 35     531 Upper Cross Street #01-07, Hong Lim Complex
# 114  JForte Sportainment Centre, 50 Hougang Ave 1, ...

# %%
import requests
import time
import pandas as pd

API_KEY = "AIzaSyC6M-BJbnUubBk1CvFVoxdC21_zxdsaCSE"

# Coordinates roughly covering Singapore’s main regions
locations = [
    (1.3521, 103.8198),  # Central
    (1.2800, 103.8500),  # Downtown
    (1.3000, 103.9000),  # East
    (1.3400, 103.7000),  # West
    (1.4000, 103.9000),  # North
    (1.3700, 103.8000),  # North-Central
]

places = []

for lat, lng in locations:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius=5000&keyword=Anytime+Fitness&key={API_KEY}"
    
    while True:
        response = requests.get(url)
        data = response.json()
        
        for place in data.get("results", []):
            name = place.get("name")
            rating = place.get("rating")
            address = place.get("vicinity")
            places.append((name, rating, address))
        
        token = data.get("next_page_token")
        if not token:
            break
        time.sleep(2)
        url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken={token}&key={API_KEY}"

# Convert to DataFrame and remove duplicates
df = pd.DataFrame(places, columns=["Outlet", "Rating", "Address"]).drop_duplicates("Outlet")
print("Total outlets found:", len(df))
print(df.sort_values("Rating"))
# Out:
# Total outlets found: 101
#                                  Outlet  Rating  \
# 60        Anytime Fitness The Concourse     3.2
# 136              Anytime Fitness hillV2     3.2
# 117          Anytime Fitness Hwi Yoh CC     3.3
# 35   Anytime Fitness Upper Cross Street     3.5
# 114               Anytime Fitness Kovan     3.6
# ..                                  ...     ...
# 108              Anytime Fitness Jurong     5.0
# 74            Anytime Fitness Joo Chiat     5.0
# 73        Anytime Fitness Simpang Bedok     5.0
# 28               Anytime Fitness Dakota     5.0
# 92      Anytime Fitness MacPherson Mall     5.0
#
#                                                Address
# 60                 300 Beach Rd, #02-01A/02, Singapore
# 136              4 Hillview Rise, #02-18/19, Singapore
# 117  23 Serangoon North Ave 4, #01-01 Hwi Yoh Commu...
# 35     531 Upper Cross Street #01-07, Hong Lim Complex
# 114  JForte Sportainment Centre, 50 Hougang Ave 1, ...
# ..                                                 ...
# 108  Block 442 Jurong West Ave 1, #01-746 to #01-74...
# 74              Joo Chiat Rd, #123/125 125A, Singapore
# 73        430 Upper Changi Rd, #01-47/48/49, Singapore
# 28      87 Jln. Satu, #02-01 Mountbatten CC, Singapore
# 92   401 MacPherson Rd, B1-01 MacPherson Mall, Sing...
#
# [101 rows x 3 columns]

# %%
import requests
import time
import pandas as pd

API_KEY = "AIzaSyC6M-BJbnUubBk1CvFVoxdC21_zxdsaCSE"

# Expanded grid across Singapore
locations = [
    (1.3521, 103.8198),  # Central
    (1.2800, 103.8500),  # Downtown
    (1.3000, 103.9000),  # East
    (1.3400, 103.7000),  # West
    (1.4000, 103.9000),  # North
    (1.3700, 103.8000),  # North-Central
    (1.3100, 103.7700),  # Southwest
    (1.4200, 103.7600),  # Northwest
    (1.2900, 103.8200),  # Southeast
]

places = []

for lat, lng in locations:
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius=5000&keyword=Anytime+Fitness&key={API_KEY}"
    
    while True:
        response = requests.get(url)
        data = response.json()
        
        for place in data.get("results", []):
            name = place.get("name")
            rating = place.get("rating")
            address = place.get("vicinity")
            maps_link = f"https://www.google.com/maps/search/?api=1&query={name.replace(' ', '+')}+{address.replace(' ', '+')}"
            places.append((name, rating, address, maps_link))
        
        token = data.get("next_page_token")
        if not token:
            break
        time.sleep(2)
        url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken={token}&key={API_KEY}"

# Convert to DataFrame and remove duplicates
df = pd.DataFrame(places, columns=["Outlet", "Rating", "Address", "MapLink"]).drop_duplicates("Outlet")
print("Total outlets found:", len(df))
(df.sort_values("Rating")).head()
# Out:
# Total outlets found: 120
#                                  Outlet  Rating  \
# 57        Anytime Fitness The Concourse     3.2
# 135              Anytime Fitness hillV2     3.2
# 116          Anytime Fitness Hwi Yoh CC     3.3
# 32   Anytime Fitness Upper Cross Street     3.5
# 89           Anytime Fitness Guillemard     3.6
#
#                                                Address  \
# 57                 300 Beach Rd, #02-01A/02, Singapore
# 135              4 Hillview Rise, #02-18/19, Singapore
# 116  23 Serangoon North Ave 4, #01-01 Hwi Yoh Commu...
# 32     531 Upper Cross Street #01-07, Hong Lim Complex
# 89                100 Guillemard Rd, #01-08, Singapore
#
#                                                MapLink
# 57   https://www.google.com/maps/search/?api=1&quer...
# 135  https://www.google.com/maps/search/?api=1&quer...
# 116  https://www.google.com/maps/search/?api=1&quer...
# 32   https://www.google.com/maps/search/?api=1&quer...
# 89   https://www.google.com/maps/search/?api=1&quer...

# %%
(df.sort_values("Rating")).head()
